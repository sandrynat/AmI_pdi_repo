# %% [markdown]
# #Automatically Detecting Stops in Trajectories using Scikit-Mobility
#
# 1) Reading a csv into a dataframe with GPS reading of trajectories made by different users with the following structure: latitude, longiture, user_id, datetime

# %%
# import pandas as pd
# from google.colab import files

# uploaded = files.upload()

# %%
#pip install scikit-mobility

# %%
import skmob
import pandas as pd
import numpy as np
from skmob.preprocessing import detection
# read the trajectory data (GeoLife)
url = 'context_dataset_v1.csv'
df = pd.read_csv(url, sep=',')
tdf = skmob.TrajDataFrame(df, latitude='location_lat', longitude='location_lon', user_id='user_x', datetime='time_t')
tdf
# Out:
#                 time            datetime        lat        lng  \
# 0      1525666992353 2018-05-07 05:23:12  43.702109  10.400969
# 1      1520875794472 2018-03-12 17:29:54  43.719917  10.422036
# 2      1521047383369 2018-03-14 17:09:43  43.719917  10.422036
# 3      1520872866143 2018-03-12 16:41:06  43.718449  10.423058
# 4      1520872926143 2018-03-12 16:42:06  43.718449  10.423058
# ...              ...                 ...        ...        ...
# 45676  1522411614683 2018-03-30 13:06:54  43.718588  10.422543
# 45677  1522411674683 2018-03-30 13:07:54  43.718588  10.422543
# 45678  1522411734683 2018-03-30 13:08:54  43.718588  10.422543
# 45679  1522411794683 2018-03-30 13:09:54  43.718588  10.422543
# 45680  1522411854683 2018-03-30 13:10:54  43.718590  10.422563
#
#        wifi_connected  sensor_light_mean  sensor_accelerometer_x_mean  \
# 0                   0           0.491083                    -0.841768
# 1                   0        2313.365000                     0.090955
# 2                   0        4693.660000                    -0.081390
# 3                   0         399.206400                    -0.017048
# 4                   0         358.872934                    -0.012993
# ...               ...                ...                          ...
# 45676               1        5540.054054                    -0.236280
# 45677               1        5540.054054                     0.046685
# 45678               1        5540.054054                    -0.906800
# 45679               0        5540.054054                    -0.180495
# 45680               0        5540.054054                    -1.395840
#
#        sensor_accelerometer_y_mean  sensor_accelerometer_z_mean  \
# 0                        -9.798033                     0.893719
# 1                        -0.035095                     9.941500
# 2                        -0.004915                     9.928235
# 3                        -0.058225                     9.914915
# 4                        -0.063340                     9.914752
# ...                            ...                          ...
# 45676                    -9.867495                    -0.841630
# 45677                    -9.941655                    -1.194635
# 45678                    -9.309720                    -2.164250
# 45679                   -10.570415                    -1.179730
# 45680                    -9.512935                    -1.189455
#
#        sensor_gravity_x_mean  ...  sensor_linear_acc_x_mean  \
# 0                   3.690201  ...                 -3.178609
# 1                   0.090053  ...                  0.000720
# 2                  -0.085803  ...                  0.004413
# 3                  -0.020499  ...                  0.000341
# 4                  -0.012417  ...                  0.001090
# ...                      ...  ...                       ...
# 45676               0.032914  ...                 -0.269194
# 45677               0.002404  ...                  0.044226
# 45678              -0.925490  ...                  0.020100
# 45679               0.055294  ...                 -0.227864
# 45680              -1.486983  ...                  0.095241
#
#        sensor_linear_acc_y_mean  sensor_linear_acc_z_mean  \
# 0                     -4.835157                  0.029616
# 1                      0.000559                  0.135715
# 2                      0.021426                  0.122015
# 3                      0.005610                  0.000917
# 4                     -0.000354                  0.001047
# ...                         ...                       ...
# 45676                 -0.531366                  0.948790
# 45677                 -0.586462                  0.568400
# 45678                  0.067008                  0.171119
# 45679                 -1.232717                  0.417479
# 45680                  0.017971                  0.072995
#
#        sensor_rotation_vec_x_mean  sensor_rotation_vec_y_mean  \
# 0                       -0.531964                   -0.058802
# 1                       -0.004916                   -0.000646
# 2                       -0.004425                   -0.001167
# 3                       -0.002664                   -0.000225
# 4                       -0.002985                   -0.000889
# ...                           ...                         ...
# 45676                   -0.232583                    0.727089
# 45677                   -0.244852                    0.561846
# 45678                   -0.487713                   -0.612670
# 45679                   -0.306835                   -0.294565
# 45680                   -0.737174                    0.080677
#
#        sensor_rotation_vec_z_mean  sensor_proximity_mean         label  \
# 0                       -0.286727               2.500000          Home
# 1                       -0.880064               0.500000       Working
# 2                        0.999185               0.333333       Working
# 3                        0.470244               5.000305         Break
# 4                        0.474117               5.000305         Break
# ...                           ...                    ...           ...
# 45676                   -0.602808               0.000000  Launch Break
# 45677                   -0.455302               0.000000  Launch Break
# 45678                    0.513169               0.000000  Launch Break
# 45679                    0.233445               0.000000  Launch Break
# 45680                    0.030028               0.000000  Launch Break
#
#              activity_label  uid
# 0      activity_rec_on_foot    2
# 1        activity_rec_still    3
# 2        activity_rec_still    3
# 3        activity_rec_still    1
# 4        activity_rec_still    1
# ...                     ...  ...
# 45676  activity_rec_on_foot    3
# 45677  activity_rec_on_foot    3
# 45678  activity_rec_on_foot    3
# 45679  activity_rec_on_foot    3
# 45680  activity_rec_on_foot    3
#
# [45681 rows x 25 columns]

# %% [markdown]
# 2) Detecting stops in these trajectories specifying minimum stop time and a radius in km
#
# https://scikit-mobility.github.io/scikit-mobility/reference/preprocessing.html#skmob.preprocessing.detection.stay_locations

# %%
stdf = detection.stay_locations(tdf, stop_radius_factor=0.5, minutes_for_a_stop=20.0, spatial_radius_km=0.2, leaving_time=True)
stdf
# Out:
#               time            datetime        lat        lng  wifi_connected  \
# 0    1520874394710 2018-03-12 16:41:06  43.718449  10.422657               1
# 1    1520882821079 2018-03-12 19:06:01  43.701253  10.402322               0
# 2    1520926892615 2018-03-12 19:31:01  43.701233  10.402322               0
# 3    1520929412615 2018-03-13 07:45:32  43.701246  10.402321               0
# 4    1520936172149 2018-03-13 09:31:12  43.719485  10.421907               0
# ..             ...                 ...        ...        ...             ...
# 445  1522393387315 2018-03-30 00:59:26  43.714313  10.416257               1
# 446  1522395094347 2018-03-30 08:09:07  43.714313  10.416230               0
# 447  1522404932054 2018-03-30 08:42:34  43.719918  10.422036               1
# 448  1522405652054 2018-03-30 11:16:32  43.718513  10.427891               1
# 449  1522409094683 2018-03-30 11:50:54  43.722227  10.424690               0
#
#      sensor_light_mean  sensor_accelerometer_x_mean  \
# 0           257.975575                    -4.157792
# 1             1.689863                     0.014816
# 2             1.689863                    -2.862386
# 3             1.689863                    -2.862386
# 4           125.962913                    -2.195862
# ..                 ...                          ...
# 445         283.125000                    -8.965945
# 446          74.857143                     0.775850
# 447        9243.200000                    -0.008825
# 448       10169.900000                    -0.964245
# 449        4698.217391                     0.304570
#
#      sensor_accelerometer_y_mean  sensor_accelerometer_z_mean  \
# 0                       8.615661                    -1.916967
# 1                      -0.143928                     9.869295
# 2                       4.545425                     8.284350
# 3                       4.545425                     8.284350
# 4                      -9.447113                    -0.558394
# ..                           ...                          ...
# 445                    -3.245095                    -2.343125
# 446                    -4.881135                    -8.056230
# 447                     0.009305                     9.967700
# 448                    -0.608140                     7.223885
# 449                    -0.258995                    10.081735
#
#      sensor_gravity_x_mean  ...  sensor_linear_acc_y_mean  \
# 0                -4.227128  ...                  0.023709
# 1                 0.014143  ...                  0.000115
# 2                -2.863062  ...                  0.071294
# 3                -2.863062  ...                  0.071294
# 4                -2.139991  ...                 -0.002318
# ..                     ...  ...                       ...
# 445              -8.954188  ...                 -0.003404
# 446               0.719719  ...                 -0.789980
# 447              -0.008776  ...                  0.000146
# 448              -0.652514  ...                 -0.127210
# 449               0.293932  ...                 -0.003805
#
#      sensor_linear_acc_z_mean  sensor_rotation_vec_x_mean  \
# 0                    0.020389                    0.088427
# 1                   -0.000439                   -0.006166
# 2                    0.000089                    0.201812
# 3                    0.000089                    0.201812
# 4                    0.008244                   -0.504787
# ..                        ...                         ...
# 445                 -0.003444                   -0.528223
# 446                  0.410698                   -0.053649
# 447                  0.161155                   -0.000415
# 448                  0.120621                   -0.081929
# 449                  0.282846                    0.012585
#
#      sensor_rotation_vec_y_mean  sensor_rotation_vec_z_mean  \
# 0                      0.768910                    0.533013
# 1                      0.003968                   -0.621208
# 2                     -0.196298                   -0.934624
# 3                     -0.196298                   -0.934624
# 4                      0.511778                   -0.364800
# ..                          ...                         ...
# 445                    0.583318                    0.233728
# 446                   -0.838681                    0.201849
# 447                    0.000487                    0.997533
# 448                   -0.030226                    0.776495
# 449                   -0.015372                    0.985571
#
#      sensor_proximity_mean         label           activity_label  uid  \
# 0                 5.000305       Working       activity_rec_still    1
# 1                 5.000305          Home       activity_rec_still    1
# 2                 5.000305          Home       activity_rec_still    1
# 3                 5.000305          Home       activity_rec_still    1
# 4                 1.666768       Working       activity_rec_still    1
# ..                     ...           ...                      ...  ...
# 445               0.333333          Home       activity_rec_still    3
# 446               0.500000     Free time  activity_rec_on_bicycle    3
# 447               0.500000       Working       activity_rec_still    3
# 448               0.500000       Working       activity_rec_still    3
# 449               0.500000  Launch Break       activity_rec_still    3
#
#        leaving_datetime
# 0   2018-03-12 19:06:01
# 1   2018-03-12 19:28:01
# 2   2018-03-13 07:42:32
# 3   2018-03-13 09:31:12
# 4   2018-03-13 12:24:04
# ..                  ...
# 445 2018-03-30 08:04:07
# 446 2018-03-30 08:32:34
# 447 2018-03-30 11:16:32
# 448 2018-03-30 11:41:54
# 449 2018-03-30 12:25:54
#
# [450 rows x 26 columns]

# %%
print('Points of the original trajectory:\t%s'%len(tdf))
print('Points of stops:\t\t\t%s'%len(stdf))
# Out:
# Points of the original trajectory:	45681
# Points of stops:			450

# %% [markdown]
# 3) Identify each trajectory by assigning the corresponding trajectory id in a separate list

# %%
#first valid trajectory id
trajectory_id = 1

#initially all trajectory ids are 0 - invalid trajectory ids
trajectory_ids_list = np.zeros(((len(tdf['datetime']))))

#first timestamp representing when the first stop was left
leaving = stdf['leaving_datetime'][0]

#timestamp representing the last moment of the previous stop
previous_trajectory=pd.Timestamp('2000-01-01')

#Am I in a stop period?
inside_stop=False
index2=0

#For each stop
for index1,stop in stdf.iterrows():
    #For each GPS point from the use who is stopped and between (stop.datetime, stop.leaving_datetime)
    for gps in tdf[(tdf.uid == stop.uid) & (tdf.datetime <= stop.leaving_datetime) & (tdf.datetime >= previous_trajectory)]['datetime']:
        if stop.datetime == gps:                  #stop detected, starting point
            leaving=stop.leaving_datetime
            inside_stop=True
            trajectory_id= trajectory_id + 1
            trajectory_ids_list[index2]=-1
        elif inside_stop == True:     #inside a stop period
            if leaving == gps:                  #this stop leaving point
                inside_stop=False
                previous_trajectory=gps
            trajectory_ids_list[index2]=-1
        else: #inside a moving point
            trajectory_ids_list[index2]=trajectory_id
        index2=index2 + 1

# %%
#The stops
print(len(stdf))

#The list of trajectory ids created is of the same size as the number of trajectory dataframe rows
print(len(trajectory_ids_list))
print(len(tdf['datetime']))

#The trajectory ids are in a increasing order, when -1 the user is on a stop, 0s are the GPs points not considered (e.g. the last ones)
print(trajectory_ids_list)
# Out:
# 450
# 45681
# 45681
# [-1. -1. -1. ...  0.  0.  0.]

# %% [markdown]
# 4) Integrating the trajectory ids list into the trajectory dataframe

# %%
tdf['trajectory_id']=trajectory_ids_list
tdf
# Out:
#                 time            datetime        lat        lng  \
# 0      1525666992353 2018-05-07 05:23:12  43.702109  10.400969
# 1      1520875794472 2018-03-12 17:29:54  43.719917  10.422036
# 2      1521047383369 2018-03-14 17:09:43  43.719917  10.422036
# 3      1520872866143 2018-03-12 16:41:06  43.718449  10.423058
# 4      1520872926143 2018-03-12 16:42:06  43.718449  10.423058
# ...              ...                 ...        ...        ...
# 45676  1522411614683 2018-03-30 13:06:54  43.718588  10.422543
# 45677  1522411674683 2018-03-30 13:07:54  43.718588  10.422543
# 45678  1522411734683 2018-03-30 13:08:54  43.718588  10.422543
# 45679  1522411794683 2018-03-30 13:09:54  43.718588  10.422543
# 45680  1522411854683 2018-03-30 13:10:54  43.718590  10.422563
#
#        wifi_connected  sensor_light_mean  sensor_accelerometer_x_mean  \
# 0                   0           0.491083                    -0.841768
# 1                   0        2313.365000                     0.090955
# 2                   0        4693.660000                    -0.081390
# 3                   0         399.206400                    -0.017048
# 4                   0         358.872934                    -0.012993
# ...               ...                ...                          ...
# 45676               1        5540.054054                    -0.236280
# 45677               1        5540.054054                     0.046685
# 45678               1        5540.054054                    -0.906800
# 45679               0        5540.054054                    -0.180495
# 45680               0        5540.054054                    -1.395840
#
#        sensor_accelerometer_y_mean  sensor_accelerometer_z_mean  \
# 0                        -9.798033                     0.893719
# 1                        -0.035095                     9.941500
# 2                        -0.004915                     9.928235
# 3                        -0.058225                     9.914915
# 4                        -0.063340                     9.914752
# ...                            ...                          ...
# 45676                    -9.867495                    -0.841630
# 45677                    -9.941655                    -1.194635
# 45678                    -9.309720                    -2.164250
# 45679                   -10.570415                    -1.179730
# 45680                    -9.512935                    -1.189455
#
#        sensor_gravity_x_mean  ...  sensor_linear_acc_y_mean  \
# 0                   3.690201  ...                 -4.835157
# 1                   0.090053  ...                  0.000559
# 2                  -0.085803  ...                  0.021426
# 3                  -0.020499  ...                  0.005610
# 4                  -0.012417  ...                 -0.000354
# ...                      ...  ...                       ...
# 45676               0.032914  ...                 -0.531366
# 45677               0.002404  ...                 -0.586462
# 45678              -0.925490  ...                  0.067008
# 45679               0.055294  ...                 -1.232717
# 45680              -1.486983  ...                  0.017971
#
#        sensor_linear_acc_z_mean  sensor_rotation_vec_x_mean  \
# 0                      0.029616                   -0.531964
# 1                      0.135715                   -0.004916
# 2                      0.122015                   -0.004425
# 3                      0.000917                   -0.002664
# 4                      0.001047                   -0.002985
# ...                         ...                         ...
# 45676                  0.948790                   -0.232583
# 45677                  0.568400                   -0.244852
# 45678                  0.171119                   -0.487713
# 45679                  0.417479                   -0.306835
# 45680                  0.072995                   -0.737174
#
#        sensor_rotation_vec_y_mean  sensor_rotation_vec_z_mean  \
# 0                       -0.058802                   -0.286727
# 1                       -0.000646                   -0.880064
# 2                       -0.001167                    0.999185
# 3                       -0.000225                    0.470244
# 4                       -0.000889                    0.474117
# ...                           ...                         ...
# 45676                    0.727089                   -0.602808
# 45677                    0.561846                   -0.455302
# 45678                   -0.612670                    0.513169
# 45679                   -0.294565                    0.233445
# 45680                    0.080677                    0.030028
#
#        sensor_proximity_mean         label        activity_label  uid  \
# 0                   2.500000          Home  activity_rec_on_foot    2
# 1                   0.500000       Working    activity_rec_still    3
# 2                   0.333333       Working    activity_rec_still    3
# 3                   5.000305         Break    activity_rec_still    1
# 4                   5.000305         Break    activity_rec_still    1
# ...                      ...           ...                   ...  ...
# 45676               0.000000  Launch Break  activity_rec_on_foot    3
# 45677               0.000000  Launch Break  activity_rec_on_foot    3
# 45678               0.000000  Launch Break  activity_rec_on_foot    3
# 45679               0.000000  Launch Break  activity_rec_on_foot    3
# 45680               0.000000  Launch Break  activity_rec_on_foot    3
#
#        trajectory_id
# 0               -1.0
# 1               -1.0
# 2               -1.0
# 3               -1.0
# 4               -1.0
# ...              ...
# 45676            0.0
# 45677            0.0
# 45678            0.0
# 45679            0.0
# 45680            0.0
#
# [45681 rows x 26 columns]

# %%
tdf.to_csv('context_TripsOpenData.csv')
stdf.to_csv('context_StopsOpenData.csv')
